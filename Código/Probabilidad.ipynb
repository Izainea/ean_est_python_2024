# %% [markdown]
# # Introducción a la probabilidad
#
# La probabilidad es una rama de las matemáticas que se ocupa del estudio de los eventos aleatorios y la posibilidad de que ocurran. Es una medida numérica que describe la posibilidad de que ocurra un evento en particular y se expresa como un número entre 0 y 1, donde 0 significa que el evento es imposible y 1 significa que el evento es seguro.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Algunos conceptos importantes

# %% [markdown]
# **Experimento:**
#
#
# Un *experimento* es definido como un proceso que genera resultados definidos. Estos resultado son conocidos como *Resultado experimental*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Espacio Muestral**
#
#
# El espacio muestral de un experimento es el *conjunto* de todos los resultados experimentales.
#
# A un resultado experimental también se le llama *punto muestral* para identificarlo como un elemento del espacio muestral.
#
# $$\Omega_1=\{\text{Cara}, \text{Sello}\}$$
#
# $$\Omega_2=\{\text{Defectuoso}, \text{No defectuoso}\}$$
#
# $$\Omega_4=\{1, 2, 3, 4, 5, 6\}$$

# %% [markdown]
# **Evento**
#
# Un evento es una colección de puntos muestrales.
#
# $$A \subseteq \Omega$$
#
# Por ejemplo
#
# $$A = \{1, 3, 5\}\subseteq \Omega_4$$
#
# $$B = \{2, 4, 6\}\subseteq \Omega_4$$

# %% [markdown]
# **Axiomas de Probabilidad**
#
# 1. *Axioma de no-negatividad*: La probabilidad de un evento nunca puede ser un número negativo, es decir, para cualquier evento A, la probabilidad de que ocurra A es igual o mayor que cero: $P(A) \geq 0$.
#
#
# 3. Axioma de la probabilidad de $\Omega$: La probabilidad de $\Omega$ es 1, es decir $P(\Omega)=1$.

# %% [markdown]
# ## **REGLAS DE CONTEO**
#
# *Experimentos de pasos múltiples*
#
# Considere un experimento que consiste en lanzar dos monedas. Defina los resultados experimentales en términos de las caras y cruces que se observan en las dos monedas. ¿Cuántos resultados experimentales tiene este experimento?
#
# **Paso 1**: Lanzar la primera moneda.
#
# $$\Omega_{p_1} = \{ C, S\}$$
#
# Se tienen $n_1 = 2$ puntos muestrales.
#
# **Paso 2**: Lanzar la segunda moneda.
#
# $$\Omega_{p_2} = \{ C, S\}$$
#
# Se tienen $n_2 = 2$ puntos muestrales.
#
# ### **REGLA DE LA MULTIPLICACIÓN**
#
# $$n=\text{Número total de resultados experimentales} = n_1 \cdot n_2 \cdots n_k$$
#
# En nuestro caso
#
# $$n= n_1 \cdot n_2=2\cdot 2=4$$
#
# ¿Cuáles son estos puntos muestrales?
#
# $$\Omega = \{ (C,C), (C, S), (S, C), (S, S)\}$$

# %% [markdown]
# **¿Por qué nos interesa encontrar el número de elementos del espacio muestral?**
#
# La probabilidad de un punto muestral será:
#
# $$P(X) = \cfrac{1}{n}$$
#
# Por ejemplo,
#
# $$P(C,C) = \cfrac{1}{4}$$
#
# La probabilidad de un evento será:
#
# $$P(A) = \cfrac{\#(A)}{n}$$
#
# Por ejemplo, la probabilidad de obtener dos resultados diferentes en experimento:
#
# $$A = \{ (C, S), (S, C)\}$$
#
# $$P(A) = \cfrac{2}{4} = \cfrac{1}{2}$$

# %%
3/15
# Out:
# 0.2

# %% [markdown]
# **Pregunta**
#
#
# Kentucky Power & Light ha empezado un proyecto que tiene como objetivo incrementar la capacidad de
# generación de una de sus plantas en el norte de Kentucky. El proyecto fue dividido en dos etapas
# o pasos sucesivos: etapa 1 (diseño) y etapa 2 (construcción). A pesar de que cada etapa se planeará y controlará con todo el cuidado posible, a los administrativos no les es posible pronosticar el
# tiempo exacto requerido en cada una de las etapas del proyecto. En un análisis de proyectos de
# construcción similares encuentran que la posible duración de la etapa de diseño es de 2, 3, o 4 meses y que la duración de la construcción es de 6, 7 u 8 meses. Además, debido a la necesidad urgente de más energía eléctrica, los administrativos han establecido como meta 10 meses para la
# terminación de todo el proyecto.
#
# *¿Cuál es probabilidad de cumplir con esta meta?*

# %% [markdown]
# **Solución**
#
# Experimento en dos pasos:
#
# Etapa de diseño: $n_1=3$
#
# Etapa de construcción: $n_2=3$
#
# $$n=\text{Número total de resultados experimentales} = 3 \cdot 3 = 9$$

# %%
3/9
# Out:
# 0.3333333333333333

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para cumplir con la meta tenemos entonces el evento:
#
# $$A =\{ (2, 6), (2, 7), (2, 8), (3, 6), (3, 7), (4, 6)\}$$
# Por tanto
# $$P(A) = \cfrac{6}{9} = 0.66$$
#
# La probabilidad de terminar el proyecto en la meta establecida sería de 0.66.

# %% [markdown]
# ### Combinación:
#
# Una combinación es un arreglo **no ordenado** de elementos. El número de combinaciones de $n$ elementos tomados $r$ a la vez se denota por $C(n,r)$ y se calcula como
#
# $$C(n,r) = \cfrac{n!}{(n-r)! r!},$$
#
#  donde $n!$ y $(n-r)!$,  $r!$ son factoriales.

# %% [markdown]
# *Tengo tres sabores de helado y puedo seleccionar dos. ¿Cuántas formas hay de hacerlo?*
#
# $$Sabores =\{A, B, C\}$$
#
#
#
# $$C(3,2) = \cfrac{3!}{1! 2!} = \cfrac{6}{1\cdot 2} = 3$$
#
# $$Elecciones = \{ AB, AC, BC\}$$

# %%
from math import*

# %%
comb(3,2)
# Out:
# 3

# %%
comb(15, 3)
# Out:
# 455

# %%
1/455*100
# Out:
# 0.21978021978021978

# %% [markdown]
# **Ejemplo**
#
#
# Considere un procedimiento de control de calidad en el que un inspector selecciona al azar dos de cinco piezas para probar
# que no tengan defectos. En un conjunto de cinco partes, ¿cuántas combinaciones de dos partes
# pueden seleccionarse?
#
# $n=5$
#
# $r=2$

# %%
comb(5, 2)
# Out:
# 10

# %% [markdown]
# $$\Omega = \{12, 13, 14, 15, 23, 24, 25, 34, 35, 45\}$$

# %% [markdown]
# **Ejemplo**
#
# Considere la lotería de Florida en la que se seleccionan seis números de un conjunto de 53 números para determinar al ganador de la semana. ¿Cuántos juegos diferentes pueden realizarse?
#
# $n=53$
#
# $r=6$

# %%
comb(53, 6)
# Out:
# 22957480

# %%
1/comb(53, 6)
# Out:
# 4.355878781120576e-08

# %%
0.0000000435
# Out:
# 4.35e-08

# %% [markdown]
# ### **Permutación**:
#
# Una permutación es un arreglo ordenado de elementos. El número de permutaciones de $n$ elementos tomados $r$ a la vez se denota por $P(n,r)$ y se calcula como
#
# $$P(n,r) = \cfrac{n!}{(n-r)!},$$
#
# donde $n!$ denota el factorial de $n$, es decir, el producto de todos los enteros positivos desde 1 hasta $n$.

# %% [markdown]
# **Ejemplo**
#
# Reconsidere el proceso de control de calidad en el que un inspector selecciona dos de cinco piezas para probar que no tienen defectos. ¿Cuántas permutaciones puede
# seleccionar?

# %%
perm(5,2)
# Out:
# 20

# %% [markdown]
# $$\Omega = \{12, 13, 14, 15, 23, 24, 25, 34, 35, 45,$$
# $$ 21, 31, 41, 51, 32, 42, 52, 43, 53, 54\}$$

# %% [markdown]
# **Ejemplo**
#
#  ¿De cuántas maneras es posible seleccionar tres objetos de un conjunto de seis objetos? Use las letras A, B, C, D, E y F para identificar a los objetos y enumere todas las combinaciones diferentes de tres objetos

# %%
comb(6,3)
# Out:
# 20

# %%
from itertools import combinations

letras = ['A', 'B', 'C', 'D', 'E', 'F']

combinaciones = list(combinations(letras, 3))

for combinacion in combinaciones:
    print(combinacion)
# Out:
# ('A', 'B', 'C')
# ('A', 'B', 'D')
# ('A', 'B', 'E')
# ('A', 'B', 'F')
# ('A', 'C', 'D')
# ('A', 'C', 'E')
# ('A', 'C', 'F')
# ('A', 'D', 'E')
# ('A', 'D', 'F')
# ('A', 'E', 'F')
# ('B', 'C', 'D')
# ('B', 'C', 'E')
# ('B', 'C', 'F')
# ('B', 'D', 'E')
# ('B', 'D', 'F')
# ('B', 'E', 'F')
# ('C', 'D', 'E')
# ('C', 'D', 'F')
# ('C', 'E', 'F')
# ('D', 'E', 'F')

# %% [markdown]
# y las permutaciones???

# %%
perm(6, 3)
# Out:
# 120

# %%
from itertools import permutations

permutaciones = list(permutations(letras, 3))

for permutacion in permutaciones:
    print(permutacion)
# Out:
# ('A', 'B', 'C')
# ('A', 'B', 'D')
# ('A', 'B', 'E')
# ('A', 'B', 'F')
# ('A', 'C', 'B')
# ('A', 'C', 'D')
# ('A', 'C', 'E')
# ('A', 'C', 'F')
# ('A', 'D', 'B')
# ('A', 'D', 'C')
# ('A', 'D', 'E')
# ('A', 'D', 'F')
# ('A', 'E', 'B')
# ('A', 'E', 'C')
# ('A', 'E', 'D')
# ('A', 'E', 'F')
# ('A', 'F', 'B')
# ('A', 'F', 'C')
# ('A', 'F', 'D')
# ('A', 'F', 'E')
# ('B', 'A', 'C')
# ('B', 'A', 'D')
# ('B', 'A', 'E')
# ('B', 'A', 'F')
# ('B', 'C', 'A')
# ('B', 'C', 'D')
# ('B', 'C', 'E')
# ('B', 'C', 'F')
# ('B', 'D', 'A')
# ('B', 'D', 'C')
# ('B', 'D', 'E')
# ('B', 'D', 'F')
# ('B', 'E', 'A')
# ('B', 'E', 'C')
# ('B', 'E', 'D')
# ('B', 'E', 'F')
# ('B', 'F', 'A')
# ('B', 'F', 'C')
# ('B', 'F', 'D')
# ('B', 'F', 'E')
# ('C', 'A', 'B')
# ('C', 'A', 'D')
# ('C', 'A', 'E')
# ('C', 'A', 'F')
# ('C', 'B', 'A')
# ('C', 'B', 'D')
# ('C', 'B', 'E')
# ('C', 'B', 'F')
# ('C', 'D', 'A')
# ('C', 'D', 'B')
# ('C', 'D', 'E')
# ('C', 'D', 'F')
# ('C', 'E', 'A')
# ('C', 'E', 'B')
# ('C', 'E', 'D')
# ...

# %%
5/120
# Out:
# 0.041666666666666664

# %% [markdown]
# ## Ejercicios fáciles
# 1. Si lanzas un dado justo, ¿cuál es la probabilidad de que salga un 3?
# 2. Si tienes una baraja de cartas española y sacas una carta al azar, ¿cuál es la probabilidad de que sea un as?
# 3. Si lanzas dos monedas justas, ¿cuál es la probabilidad de que salgan dos caras?
# 4. Si tienes una bolsa con 10 canicas rojas y 5 canicas azules, ¿cuál es la probabilidad de sacar una canica roja al azar?
# 5. Si tienes un frasco con 20 caramelos, 10 son de fresa y 10 son de limón, ¿cuál es la probabilidad de sacar un caramelo de limón al azar?
# 6. Si tienes un reloj con números del 1 al 12, ¿cuál es la probabilidad de que la manecilla de las horas apunte a un número par?
# 7. Si lanzas una moneda al aire y sacas una carta al azar de una baraja de 52 cartas, ¿cuál es la probabilidad de que salga cara y sea un as al mismo tiempo?
# 8. Si tienes una urna con 6 bolas blancas y 4 bolas negras, y extraes 3 bolas  al azar sin reemplazo ¿cuál es la probabilidad de sacar 3 bolas blancas?
# 9. Si tienes un tablero de ajedrez y mueves un peón al azar, ¿cuál es la probabilidad de que sea un peón blanco?
# 10. Si lanzas un dado justo dos veces, ¿cuál es la probabilidad de que salgan dos números pares?
# 11. Si tienes una baraja de cartas francesa y sacas una carta al azar, ¿cuál es la probabilidad de que sea una carta roja?
# 12. Si tienes una urna con 5 bolas rojas, 3 bolas verdes y 2 bolas azules, sí se extraen dos al azar y sin reemplazo ¿cuál es la probabilidad de sacar una bola roja y una bola verde ?
# 13. Si tienes una bolsa con 8 caramelos, 4 son de cereza y 4 son de manzana, ¿cuál es la probabilidad de sacar dos caramelos de cereza al azar sin reemplazo?
# 14. Si tienes un frasco con 30 canicas, 10 son rojas, 10 son verdes y 10 son azules, ¿cuál es la probabilidad de sacar una canica verde al azar?
# 15. Si lanzas dos dados justos, ¿cuál es la probabilidad de que la suma de los dos números sea 7?

# %%
4/52
# Out:
# 0.07692307692307693

# %% [markdown]
# ## Ejercicios mas complejos
# 1. En una mesa hay 3 cartas boca abajo, cada una de las cuales tiene un número entero de 1 a 10 escrito en ella. Si se seleccionan dos cartas al azar, ¿cuál es la probabilidad de que la suma de los números en ellas sea igual a 8?
# 2. Una empresa produce 5 tipos de productos, cada uno con una probabilidad del 10% de ser defectuoso. Se seleccionan 4 productos al azar para ser revisados. ¿Cuál es la probabilidad de que exactamente 3 de ellos sean defectuosos?
# 3. Se tienen 5 dados justos, cada uno con un número del 1 al 6 en sus caras. Se lanzan los 5 dados al mismo tiempo. ¿Cuál es la probabilidad de que la suma de los números en las caras de los dados sea igual a 20?
# 4. Se tienen dos monedas justas. Se lanzan las dos monedas al mismo tiempo y se registran los resultados. Si ambos resultados son iguales, se lanza una moneda adicional. ¿Cuál es la probabilidad de que los tres lanzamientos de moneda resulten en cara?
# 5. Se tienen tres urnas, cada una de las cuales contiene una bola roja y una bola verde. Se selecciona al azar una urna y se extrae una bola. Si la bola es roja, se devuelve a la urna y se agrega otra bola roja. Si la bola es verde, se devuelve a la urna y se agrega otra bola verde. Si se repite este proceso 4 veces, ¿cuál es la probabilidad de que se extraigan exactamente 2 bolas rojas y 2 bolas verdes?
# 6. En una caja hay 10 fichas numeradas del 1 al 10. Se extraen tres fichas al azar sin reemplazo. ¿Cuál es la probabilidad de que la suma de los números en las fichas sea un múltiplo de 3?

# %% [markdown]
# # ASIGNACIÓN DE PROBABILIDADES
#
# Existen tres métodos:
#
# * Método clásico
# * Método de la frecuencia relativa
# * Método subjetivo
#
# Sin importar el método usado, es necesario que se cumplan los axiomas de probabilidad.

# %% [markdown]
# ## Método clásico
#
# El método clásico de asignación de probabilidades es apropiado cuando todos los resultados
# experimentales tienen la misma posibilidad. Si existen $n$ resultados experimentales, la probabilidad
# asignada a cada resultado experimental es $\cfrac{1}{n}$.

# %% [markdown]
# ## Método de frecuencia relativa
#
# El método de frecuencia relativa para la asignación de probabilidades es el más conveniente
# cuando existen datos para estimar la proporción de veces que se presentarán los resultados si
# el experimento se repite muchas veces.

# %%
## Pandas datafrmaes y variables
import pandas as pd
## Numerical Python
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from scipy.stats import chi2_contingency

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Carga de los datos**

# %%
ruta_archivo ="/content/drive/MyDrive/Fundamentos de estadística para la analítica de datos/Bases de datos/Saber_11__2019-2.csv"
datos = pd.read_csv(ruta_archivo)
# Out:
# <ipython-input-22-02ad9364cdb3>:2: DtypeWarning: Columns (76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos = pd.read_csv(ruta_archivo)

# %%
datos = pd.read_csv(ruta_archivo, na_values="-", index_col=5)
datos
# Out:
#                  ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# ESTU_CONSECUTIVO
# SB11201940031558                 TI          COLOMBIA           M
# SB11201940303339                 TI          COLOMBIA           M
# SB11201940255017                 TI          COLOMBIA           M
# SB11201940154799                 TI          COLOMBIA           M
# SB11201940280831                 TI          COLOMBIA           M
# ...                             ...               ...         ...
# SB11201940195862                 CC          COLOMBIA           M
# SB11201940253002                 TI          COLOMBIA           M
# SB11201940364767                 TI          COLOMBIA           M
# SB11201940210026                 TI          COLOMBIA           M
# SB11201940074679                 TI          COLOMBIA           M
#
#                     ESTU_FECHANACIMIENTO  PERIODO ESTU_ESTUDIANTE  \
# ESTU_CONSECUTIVO
# SB11201940031558  02/18/2002 12:00:00 AM    20194      ESTUDIANTE
# ...

# %%
TablaFa=datos.groupby("ESTU_GENERO", as_index=False).size()
TablaFa
# Out:
#   ESTU_GENERO    size
# 0           F  295994
# 1           M  250097

# %%
total = sum(TablaFa["size"])
total
# Out:
# 546091

# %%
TablaFa["Relativa"] = TablaFa["size"]/total
TablaFa
# Out:
#   ESTU_GENERO    size  Relativa
# 0           F  295994  0.542023
# 1           M  250097  0.457977

# %% [markdown]
# La probabilidad de seleccionar un estudiante al azar entre quienes presentaron la prueba Saber 11 2019-2 y:
#
# * Encontrar una persona de género Femenino es de 0.54
# * Encontrar una persona de género Masculino es de 0.46

# %% [markdown]
# **Una forma más rápida**

# %%
datos.shape
# Out:
# (546212, 81)

# %%
datos.groupby("FAMI_ESTRATOVIVIENDA", dropna=False).size()/datos.shape[0]
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 1      0.292884
# Estrato 2      0.344764
# Estrato 3      0.198992
# Estrato 4      0.047253
# Estrato 5      0.014690
# Estrato 6      0.006794
# Sin Estrato    0.031447
# NaN            0.063175
# dtype: float64

# %% [markdown]
# ## Método subjetivo
#
# El método subjetivo de asignación de probabilidades es el más indicado cuando no es factible suponer que todos los resultados de un experimento sean igualmente posibles y, además, cuenta con pocos datos relevantes. El método subjetivo de asignación de probabilidades a los resultados de un
# experimento, usa toda la información disponible, por ejemplo, la propia experiencia o la intuición.

# %% [markdown]
# # Propiedades conjuntistas de la probabilidad
#
# ## Complemento de un evento
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $$P(A^c) =1- P(A)$$

# %%
datos.groupby("FAMI_ESTRATOVIVIENDA", dropna=False).size()/datos.shape[0]
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 1      0.292884
# Estrato 2      0.344764
# Estrato 3      0.198992
# Estrato 4      0.047253
# Estrato 5      0.014690
# Estrato 6      0.006794
# Sin Estrato    0.031447
# NaN            0.063175
# dtype: float64

# %% [markdown]
# ¿Cuál es la probabilidad de ser de estrato 4?
#
# $$P(E=4) = 0.047$$
#
# ¿Cuál es la probabilidad de no ser de estrato 4?
#
#
# $$P(E \neq 4) = 1- 0.047$$

# %%
1- 0.047
# Out:
# 0.953

# %% [markdown]
# $$P(E4 \neq 4) = 0.953$$

# %% [markdown]
# ## Intersección de eventos
#
# Usada cuando se requiere intesecar eventos:
#
#
# * Ser mujer **y** ser de un colegio oficial.
# * Masculido **y** ser de un colegio No oficial.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.crosstab(datos["ESTU_GENERO"], datos['COLE_NATURALEZA'])
# Out:
# COLE_NATURALEZA  NO OFICIAL  OFICIAL
# ESTU_GENERO
# F                     65437   230557
# M                     64737   185360

# %%
pd.crosstab(datos["ESTU_GENERO"], datos['COLE_NATURALEZA'])/datos.shape[0] # Ojo entre quien se divide
# Out:
# COLE_NATURALEZA  NO OFICIAL   OFICIAL
# ESTU_GENERO
# F                  0.119801  0.422102
# M                  0.118520  0.339355

# %% [markdown]
# Por tanto:
#
#
# * La probabilidad de ser mujer **y** ser de un colegio oficial es de 0.42.
# * La probabilidad de tener género masculino **y** ser de un colegio No oficial es del 0.34

# %% [markdown]
# ## Ley de la adición
#
# La usaremos cuando necesitemos la probabilidad de una unión.
#
# **Ejemplo**
#
# * ¿Cuál es la probabilidad de ser de estrato 5 o 6?
#
# * ¿Cuál es la probabilidad de ?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $$P(A \cup B) = P(A)+P(B)-P(A \cap B)$$

# %% [markdown]
# **Ejemplo**
#
# Considere un estudio reciente efectuado por el
# director de personal de una empresa importante de software. En el estudio encontró que 30% de los empleados que se van de la empresa antes de dos años, lo hacen por estar insatisfechos con el salario, 20% se van de la empresa por estar descontentos con el trabajo y 12% por estar insatisfechos con las dos cosas, el salario y el trabajo. ¿Cuál es la probabilidad de que un empleado que se vaya de la empresa en menos de dos años lo haga por estar insatisfecho con el salario, con el trabajo o con las dos cosas?

# %% [markdown]
# $IS =$ {Insatisfechos con el salario}
#
# $DT =$ {Descontentos con el trabajo}
#
# $IS \cap DT = $ {Insatisfechos con el salario **y** descontentos con el trabajo}
#
#
# $$P(IS \cap DT) =$$

# %%
0.30+0.20-0.12
# Out:
# 0.38

# %% [markdown]
# $$P(IS \cap DT) = 0.38$$$

# %% [markdown]
# ### EVENTOS MUTUAMENTE EXCLUYENTES
# Se dice que dos eventos son mutuamente excluyentes si no tienen puntos muestrales en
# común.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $$P(A∪B)=P(A)+P(B)$$

# %% [markdown]
# ¿Cuál es la probabilidad de ser estrato 4 o 5?

# %%
datos.groupby("FAMI_ESTRATOVIVIENDA", dropna=False).size()/datos.shape[0]
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 1      0.292884
# Estrato 2      0.344764
# Estrato 3      0.198992
# Estrato 4      0.047253
# Estrato 5      0.014690
# Estrato 6      0.006794
# Sin Estrato    0.031447
# NaN            0.063175
# dtype: float64

# %% [markdown]
# Como son dos eventos mutuamente excluyentes tenemos que $P(E=4, \vee, E=5)=0.061943$

# %%
0.047253+ 0.014690
# Out:
# 0.061943000000000005

# %% [markdown]
# ## Probabilidad condicional
#
# La probabilidad condicional es la probabilidad de que ocurra un evento $A$, dado que ya ha ocurrido un evento $B$. Se representa por $P(A|B)$ y se lee como **"la probabilidad de A dado B"**. La fórmula para la probabilidad condicional es:
#
# $$P(A|B) = \frac{P(A \cap B) }{ P(B)}$$
#
# donde $P(A \cap B) $ es la probabilidad de que ambos eventos $A$ y $B$ ocurran juntos, y $P(B)$ es la probabilidad de que ocurra el evento $B$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La probabilidad de ser promovido dado que se es hombre:
#
# $$P(A | M=\cfrac{P(A \cap M)}{P(M)}$$

# %%
0.24/0.80
# Out:
# 0.3

# %% [markdown]
# $$P(A | M=\cfrac{P(A \cap M)}{P(M)}= 0.30$$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La probabilidad de ser promovido dado que se es mujer:
#
# $$P(A | W)=\cfrac{P(A \cap W)}{P(W)}$$

# %%
0.03/0.20
# Out:
# 0.15

# %% [markdown]
# $$P(A | W)=\cfrac{P(A \cap W)}{P(W)}=0.15$$

# %% [markdown]
# ¿Cuál es la probabilidad de tener un puntaje en ingles mayor a 75 si se sabe que el estudiante es de estrato 5?

# %%
pd.crosstab(datos["FAMI_ESTRATOVIVIENDA"], datos['PUNT_INGLES'])/datos.shape[0]
# Out:
# PUNT_INGLES              0.0       20.0      21.0      22.0      23.0   \
# FAMI_ESTRATOVIVIENDA
# Estrato 1             0.000033  0.000018  0.000082  0.000353  0.000948
# Estrato 2             0.000038  0.000011  0.000093  0.000258  0.000743
# Estrato 3             0.000016  0.000004  0.000044  0.000126  0.000350
# Estrato 4             0.000002  0.000002  0.000007  0.000055  0.000123
# Estrato 5             0.000000  0.000000  0.000005  0.000015  0.000042
# Estrato 6             0.000002  0.000000  0.000000  0.000011  0.000042
# Sin Estrato           0.000015  0.000004  0.000029  0.000090  0.000234
#
# PUNT_INGLES              24.0      25.0      26.0      27.0      28.0   ...  \
# FAMI_ESTRATOVIVIENDA                                                    ...
# Estrato 1             0.001336  0.001584  0.002036  0.002942  0.003530  ...
# Estrato 2             0.000970  0.001181  0.001520  0.002283  0.002536  ...
# ...

# %%
bins = [0, 25,50, 75, 100]

# %%
nombres_categorias = ['L1', 'L2', 'L3', 'L4']

# %%
datos["datos_categorizados"] = pd.cut(datos['PUNT_INGLES'], bins, labels=nombres_categorias)

# %%
datos_categorizados = pd.cut(datos['PUNT_INGLES'], bins, labels=nombres_categorias) #Assign result of pd.cut to datos_categorizados variable

# %%
datos["datos_categorizados"]
# Out:
# ESTU_CONSECUTIVO
# SB11201940031558    L3
# SB11201940303339    L3
# SB11201940255017    L3
# SB11201940154799    L3
# SB11201940280831    L3
#                     ..
# SB11201940195862    L3
# SB11201940253002    L3
# SB11201940364767    L3
# SB11201940210026    L2
# SB11201940074679    L3
# Name: datos_categorizados, Length: 546212, dtype: category
# Categories (4, object): ['L1' < 'L2' < 'L3' < 'L4']

# %%
pd.crosstab(datos["FAMI_ESTRATOVIVIENDA"], datos["datos_categorizados"])/datos.shape[0]
# Out:
# datos_categorizados         L1        L2        L3        L4
# FAMI_ESTRATOVIVIENDA
# Estrato 1             0.004322  0.203489  0.083989  0.001040
# Estrato 2             0.003257  0.188696  0.148312  0.004458
# Estrato 3             0.001465  0.080123  0.108678  0.008709
# Estrato 4             0.000518  0.015445  0.025366  0.005923
# Estrato 5             0.000203  0.005578  0.006496  0.002413
# Estrato 6             0.000183  0.003264  0.002217  0.001128
# Sin Estrato           0.001120  0.026250  0.003958  0.000099

# %%
Marginales =pd.crosstab(datos["FAMI_ESTRATOVIVIENDA"], datos["datos_categorizados"])/datos.shape[0]

# %%
Marginales.assign(Total=Marginales.sum(axis=1))
# Out:
# datos_categorizados         L1        L2        L3        L4     Total
# FAMI_ESTRATOVIVIENDA
# Estrato 1             0.004322  0.203489  0.083989  0.001040  0.292841
# Estrato 2             0.003257  0.188696  0.148312  0.004458  0.344723
# Estrato 3             0.001465  0.080123  0.108678  0.008709  0.198974
# Estrato 4             0.000518  0.015445  0.025366  0.005923  0.047251
# Estrato 5             0.000203  0.005578  0.006496  0.002413  0.014690
# Estrato 6             0.000183  0.003264  0.002217  0.001128  0.006792
# Sin Estrato           0.001120  0.026250  0.003958  0.000099  0.031427

# %% [markdown]
# $$P(\text{PUNT_INGLES} >75 |  E=5) =$$

# %%
0.002413/0.014690
# Out:
# 0.16426140231449968

# %% [markdown]
# $$P(\text{PUNT_INGLES} >75 |  E=5) =0.1642$$

# %%
total_por_columna = Marginales.sum(axis=0)
total_por_columna.name = 'Total'

# %%
# Use concat instead of append. The append method was deprecated in pandas version 1.4.0
Marginales_con_totales = pd.concat([Marginales, total_por_columna.to_frame().T], axis=0)
Marginales_con_totales
# Out:
# datos_categorizados        L1        L2        L3        L4
# Estrato 1            0.004322  0.203489  0.083989  0.001040
# Estrato 2            0.003257  0.188696  0.148312  0.004458
# Estrato 3            0.001465  0.080123  0.108678  0.008709
# Estrato 4            0.000518  0.015445  0.025366  0.005923
# Estrato 5            0.000203  0.005578  0.006496  0.002413
# Estrato 6            0.000183  0.003264  0.002217  0.001128
# Sin Estrato          0.001120  0.026250  0.003958  0.000099
# Total                0.011069  0.522845  0.379016  0.023769

# %% [markdown]
# ¿Cuál es la probabilidad de que una persona que presentó la prueba sea de estrato mayor a 3 dado que tiene un puntaje mayor a 50?

# %% [markdown]
# ¿Cuál es la probabilidad de que una persona que presentó la prueba sea de estrato 3 o menor dado que tiene un puntaje menor a 50?
